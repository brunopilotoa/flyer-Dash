# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
base = pd.read_excel("Base de Dados_Montagem Final_H23_2025.xlsx", header=1)

# %%
entregue = base.loc[base["STATUS FINAL"] == "ENTREGUE"]
entregue.drop(columns=entregue.columns[0], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_24081/3608555158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entregue.drop(columns=entregue.columns[0], axis=1, inplace=True)

# %%
entregue['Data VTI'] = pd.to_datetime(entregue['Data VTI'],format='%d%m%Y')
entregue['Data VTI']
# Out:
# /tmp/ipykernel_24081/1226572373.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entregue['Data VTI'] = pd.to_datetime(entregue['Data VTI'],format='%d%m%Y')
# 0    2023-11-29
# 1    2024-06-16
# 2    2024-06-01
# 3    2024-09-27
# 4    2025-01-22
# 5    2024-11-30
# 6    2025-02-07
# 7    2025-02-20
# 8    2025-03-04
# 9    2025-02-20
# 11   2025-03-20
# 12   2025-03-21
# 14   2025-05-07
# Name: Data VTI, dtype: datetime64[ns]

# %%
vti=entregue.iloc[:,15]
vti
# Out:
# 0    2023-11-29
# 1    2024-06-16
# 2    2024-06-01
# 3    2024-09-27
# 4    2025-01-22
# 5    2024-11-30
# 6    2025-02-07
# 7    2025-02-20
# 8    2025-03-04
# 9    2025-02-20
# 11   2025-03-20
# 12   2025-03-21
# 14   2025-05-07
# Name: Data VTI, dtype: datetime64[ns]

# %%
plt.hist(vti)
plt.show()

# %%
    df_entregue = base[base["STATUS FINAL"] == "ENTREGUE"]
    anv_entregue = df_entregue["Prefixo"]

# %%
anv_entregue
# Out:
# 0     PR-ZJI
# 1     PS-RZA
# 2     PS-ZAZ
# 3     PS-LZI
# 4     PS-BER
# 5     PS-KLA
# 6     PS-JOM
# 7     PP-JSD
# 8     PS-AGJ
# 9     PS-AAW
# 11    PS-MCG
# 12    PS-SML
# 14    PS-DGH
# Name: Prefixo, dtype: object
